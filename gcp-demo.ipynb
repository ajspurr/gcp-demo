# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ---------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.6.1
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.10.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.11.1
# binaryornot                           0.4.4
# black                                 22.3.0
# bleach                                5.0.0
# blinker                               1.4
# brotlipy                              0.7.0
# cachetools                            5.0.0
# certifi                               2021.10.8
# cffi                                  1.15.0
# chardet                               4.0.0
# charset-normalizer                    2.0.12
# click                                 8.1.3
# cloudpickle                           2.0.0
# colorama                              0.4.4
# conda                                 4.12.0
# conda-package-handling                1.8.1
# cookiecutter                          1.7.3
# cryptography                          36.0.2
# cycler                                0.11.0
# dataclasses                           0.8
# debugpy                               1.6.0
# decorator                             5.1.1
# defusedxml                            0.7.1
# docker                                5.0.3
# docker-pycreds                        0.4.0
# entrypoints                           0.4
# fastjsonschema                        2.15.3
# flit_core                             3.7.1
# fonttools                             4.33.3
# frozenlist                            1.3.0
# fsspec                                2022.3.0
# gcsfs                                 2022.3.0
# gitdb                                 4.0.9
# GitPython                             3.1.27
# google-api-core                       2.7.1
# google-api-python-client              2.47.0
# google-auth                           2.6.6
# google-auth-httplib2                  0.1.0
# google-auth-oauthlib                  0.5.1
# google-cloud-aiplatform               1.13.0
# google-cloud-appengine-logging        1.1.1
# google-cloud-audit-log                0.2.0
# google-cloud-bigquery                 2.34.3
# google-cloud-bigquery-storage         2.13.1
# google-cloud-bigtable                 2.9.0
# google-cloud-core                     2.3.0
# google-cloud-dataproc                 4.0.2
# google-cloud-datastore                2.5.1
# google-cloud-firestore                2.4.0
# google-cloud-kms                      2.11.1
# google-cloud-language                 2.4.1
# google-cloud-logging                  3.0.0
# google-cloud-monitoring               2.9.1
# google-cloud-pubsub                   1.7.0
# google-cloud-resource-manager         1.4.1
# google-cloud-scheduler                2.6.3
# google-cloud-spanner                  3.14.0
# google-cloud-speech                   2.13.1
# google-cloud-storage                  2.3.0
# google-cloud-tasks                    2.9.0
# google-cloud-translate                3.7.2
# google-cloud-videointelligence        2.7.0
# google-cloud-vision                   2.7.2
# google-crc32c                         1.1.2
# google-resumable-media                2.3.2
# googleapis-common-protos              1.56.1
# greenlet                              1.1.2
# grpc-google-iam-v1                    0.12.4
# grpcio                                1.46.1
# grpcio-gcp                            0.2.2
# grpcio-status                         1.46.1
# htmlmin                               0.1.12
# httplib2                              0.20.4
# idna                                  3.3
# ImageHash                             4.2.1
# importlib-metadata                    4.11.3
# importlib-resources                   5.7.1
# ipykernel                             6.13.0
# ipython                               7.33.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.3.9
# jedi                                  0.18.1
# jeepney                               0.8.0
# Jinja2                                3.1.2
# jinja2-time                           0.2.0
# joblib                                1.1.0
# json5                                 0.9.5
# jsonschema                            4.5.1
# jupyter-client                        7.3.1
# jupyter-core                          4.10.0
# jupyter-http-over-ws                  0.0.8
# jupyter-server                        1.17.0
# jupyter-server-mathjax                0.2.5
# jupyter-server-proxy                  3.2.1
# jupyterlab                            3.2.9
# jupyterlab-git                        0.37.1
# jupyterlab-pygments                   0.2.2
# jupyterlab-server                     2.13.0
# jupytext                              1.13.8
# keyring                               23.5.0
# keyrings.google-artifactregistry-auth 1.0.0
# kiwisolver                            1.4.2
# kubernetes                            23.6.0
# llvmlite                              0.38.0
# Markdown                              3.3.7
# markdown-it-py                        2.1.0
# MarkupSafe                            2.1.1
# matplotlib                            3.5.2
# matplotlib-inline                     0.1.3
# mdit-py-plugins                       0.3.0
# mdurl                                 0.1.0
# missingno                             0.4.2
# mistune                               0.8.4
# multidict                             6.0.2
# multimethod                           1.4
# munkres                               1.1.4
# mypy-extensions                       0.4.3
# nb-conda                              2.2.1
# nb-conda-kernels                      2.3.1
# nbclassic                             0.3.7
# nbclient                              0.6.3
# nbconvert                             6.5.0
# nbdime                                3.1.1
# nbformat                              5.4.0
# nest-asyncio                          1.5.5
# networkx                              2.7.1
# notebook                              6.4.11
# notebook-executor                     0.2
# notebook-shim                         0.1.0
# numba                                 0.55.1
# numpy                                 1.19.5
# oauthlib                              3.2.0
# packaging                             21.3
# pandas                                1.3.5
# pandas-profiling                      3.2.0
# pandocfilters                         1.5.0
# papermill                             2.3.4
# parso                                 0.8.3
# pathspec                              0.9.0
# patsy                                 0.5.2
# pexpect                               4.8.0
# phik                                  0.12.2
# pickleshare                           0.7.5
# Pillow                                9.1.0
# pip                                   22.1
# platformdirs                          2.5.1
# pluggy                                1.0.0
# poyo                                  0.5.0
# prettytable                           3.3.0
# prometheus-client                     0.14.1
# prompt-toolkit                        3.0.29
# proto-plus                            1.20.3
# protobuf                              3.20.1
# psutil                                5.9.0
# ptyprocess                            0.7.0
# pyarrow                               8.0.0
# pyasn1                                0.4.8
# pyasn1-modules                        0.2.7
# pycosat                               0.6.3
# pycparser                             2.21
# pydantic                              1.9.0
# Pygments                              2.12.0
# PyJWT                                 2.4.0
# pyOpenSSL                             22.0.0
# pyparsing                             3.0.9
# pyrsistent                            0.18.1
# PySocks                               1.7.1
# python-dateutil                       2.8.2
# python-slugify                        6.1.2
# pytz                                  2022.1
# pyu2f                                 0.1.5
# PyWavelets                            1.3.0
# PyYAML                                6.0
# pyzmq                                 22.3.0
# requests                              2.27.1
# requests-oauthlib                     1.3.1
# retrying                              1.3.3
# rsa                                   4.8
# ruamel-yaml-conda                     0.15.100
# scikit-learn                          1.0.2
# scipy                                 1.7.3
# seaborn                               0.11.2
# SecretStorage                         3.3.2
# Send2Trash                            1.8.0
# setuptools                            59.8.0
# simpervisor                           0.4
# six                                   1.16.0
# smmap                                 3.0.5
# sniffio                               1.2.0
# soupsieve                             2.3.1
# SQLAlchemy                            1.4.36
# sqlparse                              0.4.2
# statsmodels                           0.13.2
# tangled-up-in-unicode                 0.2.0
# tenacity                              8.0.1
# terminado                             0.13.3
# text-unidecode                        1.3
# textwrap3                             0.9.2
# threadpoolctl                         3.1.0
# tinycss2                              1.1.1
# toml                                  0.10.2
# tomli                                 2.0.1
# tornado                               6.1
# tqdm                                  4.64.0
# traitlets                             5.2.0
# typed-ast                             1.5.3
# typing_extensions                     4.2.0
# ujson                                 5.2.0
# unicodedata2                          14.0.0
# Unidecode                             1.3.4
# uritemplate                           4.1.1
# urllib3                               1.26.9
# visions                               0.7.4
# wcwidth                               0.2.5
# webencodings                          0.5.1
# websocket-client                      1.3.2
# wheel                                 0.37.1
# wrapt                                 1.14.1
# yarl                                  1.7.2
# zipp                                  3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7698/2457254733.py in <module>
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-manylinux2014_x86_64.whl (192.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.9/192.9 MB 5.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.19.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 15
# Out:
# Query complete after 0.01s: 100%|██████████| 1/1 [00:00<00:00, 462.13query/s]
# Downloading: 100%|██████████| 15/15 [00:01<00:00, 13.38rows/s]
#     tree_id    legal_status                                         species  \
# 0     48142  Permitted Site                                      Tree(s) ::
# 1     44866  Permitted Site                                      Tree(s) ::
# 2     34921  Permitted Site                                      Tree(s) ::
# 3     45916  Permitted Site                                      Tree(s) ::
# 4     97355  Permitted Site                                      Tree(s) ::
# 5     33929  Permitted Site                                      Tree(s) ::
# 6     44989  Permitted Site                                      Tree(s) ::
# 7     34903  Permitted Site       Magnolia grandiflora :: Southern Magnolia
# 8     44943  Permitted Site                                      Tree(s) ::
# 9     45011  Permitted Site                                      Tree(s) ::
# 10    30483  Permitted Site                                      Tree(s) ::
# 11    33087  Permitted Site  Platanus x hispanica :: Sycamore: London Plane
# 12    35187  Permitted Site      Arbutus 'Marina' :: Hybrid Strawberry Tree
# 13    46009  Permitted Site                                      Tree(s) ::
# 14    48279  Permitted Site                                      Tree(s) ::
#
#    address  site_order                     site_info plant_type care_taker  \
# 0     None         252  Sidewalk: Curb side : Cutout       Tree    Private
# 1     None          25  Sidewalk: Curb side : Cutout       Tree    Private
# 2     None           1  Sidewalk: Curb side : Cutout       Tree    Private
# 3     None          51  Sidewalk: Curb side : Cutout       Tree    Private
# 4     None           5      Unaccepted Street : Yard       Tree    Private
# 5     None           4  Sidewalk: Curb side : Cutout       Tree    Private
# 6     None          83  Sidewalk: Curb side : Cutout       Tree    Private
# 7     None           4  Sidewalk: Curb side : Cutout       Tree    Private
# 8     None         176  Sidewalk: Curb side : Cutout       Tree    Private
# 9     None          93  Sidewalk: Curb side : Cutout       Tree    Private
# 10    None           4  Sidewalk: Curb side : Cutout       Tree    Private
# 11    None           6  Sidewalk: Curb side : Cutout       Tree    Private
# 12    None          17  Sidewalk: Curb side : Cutout       Tree    Private
# 13    None         195  Sidewalk: Curb side : Cutout       Tree    Private
# 14    None          89  Sidewalk: Curb side : Cutout       Tree    Private
#
#    care_assistant                plant_date   dbh plot_size  \
# 0            None 2002-07-17 12:00:00+00:00  None      None
# 1            None 2001-04-25 12:00:00+00:00  None      None
# 2            None                       NaT  None      None
# 3            None 2001-12-06 12:00:00+00:00  None      None
# 4            None                       NaT  None      None
# 5            None 1997-03-25 12:00:00+00:00  None      None
# 6            None 2001-04-25 12:00:00+00:00  None      None
# 7            None 1997-09-05 12:00:00+00:00  None      None
# 8            None 2001-04-25 12:00:00+00:00  None      None
# 9            None 2001-04-25 12:00:00+00:00  None      None
# 10           None 1956-09-05 12:00:00+00:00  None      None
# 11           None 1996-11-05 12:00:00+00:00  None      None
# 12           None 1998-02-10 12:00:00+00:00  None      None
# 13           None 2001-12-06 12:00:00+00:00  None      None
# 14           None 2002-07-17 12:00:00+00:00  None      None
#
#            permit_notes  x_coordinate  y_coordinate  latitude  longitude  \
# 0   Permit Number 45761           NaN           NaN       NaN        NaN
# 1   Permit Number 43922           NaN           NaN       NaN        NaN
# 2   Permit Number 38517           NaN           NaN       NaN        NaN
# 3   Permit Number 44451           NaN           NaN       NaN        NaN
# 4                  None           NaN           NaN       NaN        NaN
# 5   Permit Number 37893           NaN           NaN       NaN        NaN
# 6   Permit Number 43922           NaN           NaN       NaN        NaN
# 7   Permit Number 38505           NaN           NaN       NaN        NaN
# 8   Permit Number 43922           NaN           NaN       NaN        NaN
# 9   Permit Number 43922           NaN           NaN       NaN        NaN
# 10    Permit Number 147           NaN           NaN       NaN        NaN
# 11  Permit Number 37336           NaN           NaN       NaN        NaN
# 12  Permit Number 38712           NaN           NaN       NaN        NaN
# 13  Permit Number 44451           NaN           NaN       NaN        NaN
# 14  Permit Number 45761           NaN           NaN       NaN        NaN
#
#    location
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None

# %%
# %%bigquery df_tree
# SELECT species, count(*) as num_trees, min(plant_date) as min_plant_date, max(plant_date) as max_plant_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees`
# group by species
# Out:
# Query complete after 0.00s: 100%|██████████| 2/2 [00:00<00:00, 1039.74query/s]
# Downloading: 100%|██████████| 577/577 [00:01<00:00, 478.76rows/s]

# %%
df_tree
# Out:
#                                                species  num_trees  \
# 0                                           Tree(s) ::      11786
# 1            Magnolia grandiflora :: Southern Magnolia       6399
# 2       Platanus x hispanica :: Sycamore: London Plane      11741
# 3           Arbutus 'Marina' :: Hybrid Strawberry Tree       5756
# 4                     Ginkgo biloba :: Maidenhair Tree       3273
# ..                                                 ...        ...
# 572                 Rhopalostylis sapida :: Nikau palm          1
# 573  Viburnum odoratissimum var. awabuki :: Sweet v...          6
# 574  Callistemon salignus :: White flowering bottle...          1
# 575                 Macadamia tetraphylla :: Macadamia          1
# 576                  Corylus colurna :: Hazel: Turkish          2
#
#                min_plant_date            max_plant_date
# 0   1955-09-19 12:00:00+00:00 2022-04-12 12:00:00+00:00
# 1   1955-12-13 12:00:00+00:00 2022-03-09 12:00:00+00:00
# 2   1956-02-15 12:00:00+00:00 2022-05-10 12:00:00+00:00
# 3   1956-02-06 12:00:00+00:00 2022-05-19 12:00:00+00:00
# 4   1956-02-06 12:00:00+00:00 2022-03-16 07:55:00+00:00
# ..                        ...                       ...
# 572                       NaT                       NaT
# 573                       NaT                       NaT
# 574                       NaT                       NaT
# 575                       NaT                       NaT
# 576                       NaT                       NaT
#
# [577 rows x 4 columns]
